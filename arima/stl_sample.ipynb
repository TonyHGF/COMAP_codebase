# %%
from statsmodels.datasets import co2
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters

# %%
register_matplotlib_converters()
data = co2.load().data
data = data.resample('M').mean().ffill()

from statsmodels.tsa.seasonal import STL
res = STL(data).fit()
x=res.seasonal
y=res.trend
z=res.resid
plt.subplot(3,1,1)
x.plot()
plt.subplot(3,1,2)
y.plot()
plt.subplot(3,1,3)
z.plot()
print(res)
plt.show()
# Out:
# <statsmodels.tsa.seasonal.DecomposeResult object at 0x000001EE2362B050>
