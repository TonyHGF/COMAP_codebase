# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
titanic=sns.load_dataset('titanic')

# %%
sns.barplot(x='class',y='survived',data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
#去除'age'中的缺失值，distplot不能处理缺失数据
age1=titanic['age'].dropna()

sns.distplot(age1)
# Out:
# C:\Users\Tony Hu\AppData\Local\Temp\ipykernel_17736\3425667109.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(age1)
# <Axes: xlabel='age', ylabel='Density'>

# %%
#去掉拟合的密度估计曲线，kde参数设为False
sns.distplot(age1,kde=False)
# Out:
# C:\Users\Tony Hu\AppData\Local\Temp\ipykernel_17736\2758250917.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(age1,kde=False)
# <Axes: xlabel='age'>

# %%
# 通过'bins'参数设定数据片段的数量
sns.distplot(age1,bins=30,kde=False)
# Out:
# C:\Users\Tony Hu\AppData\Local\Temp\ipykernel_17736\1486978365.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(age1,bins=30,kde=False)
# <Axes: xlabel='age'>

# %%
#创建一个一行2列的画布,主要方便对比
fig,axes=plt.subplots(1,2)

#设置'reg'参数，加上观测数值的边际毛毯
#需要用axes[]表示是第几张图，从0开始
sns.distplot(age1,ax=axes[0]) #左图
sns.distplot(age1,rug=True,ax=axes[1]) #右图
# Out:
# C:\Users\Tony Hu\AppData\Local\Temp\ipykernel_17736\1200525583.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(age1,ax=axes[0]) #左图
# C:\Users\Tony Hu\AppData\Local\Temp\ipykernel_17736\1200525583.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(age1,rug=True,ax=axes[1]) #右图
# <Axes: xlabel='age', ylabel='Density'>

# %%
#可以分别控制直方图、密度图的关键参数
fig,axes=plt.subplots(1,2) 
sns.distplot(age1,rug=True,ax=axes[0])
sns.distplot(age1,rug=True,
                     hist_kws={'color':'green','label':'hist'},
                     kde_kws={'color':'red','label':'KDE'},
                     ax=axes[1])
# Out:
# C:\Users\Tony Hu\AppData\Local\Temp\ipykernel_17736\488820128.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(age1,rug=True,ax=axes[0])
# C:\Users\Tony Hu\AppData\Local\Temp\ipykernel_17736\488820128.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(age1,rug=True,
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.barplot(x='class',y='survived',hue='sex',data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.barplot(x='embarked',y='survived',
                    hue='class',data=titanic)
# Out:
# <Axes: xlabel='embarked', ylabel='survived'>

# %%
sns.countplot(x='deck',data=titanic)
# Out:
# <Axes: xlabel='deck', ylabel='count'>

# %%
sns.countplot(x='deck',hue='sex',data=titanic)
# Out:
# <Axes: xlabel='deck', ylabel='count'>

# %%
sns.countplot(y='deck',hue='who',data=titanic)
# Out:
# <Axes: xlabel='count', ylabel='deck'>

# %%
# palette = {
#     'C': 'blue',   # 例如，C港口使用蓝色
#     'Q': 'green',  # Q港口使用绿色
#     'S': 'red'     # S港口使用红色
# }
palette = {
    'C': '#7FB3D5',  # 淡蓝色
    'Q': '#82E0AA',  # 浅绿色
    'S': '#F1948A'   # 淡红色
}
sns.stripplot(x='embarked',y='fare',data=titanic, palette=palette)
# Out:
# C:\Users\Tony Hu\AppData\Local\Temp\ipykernel_17736\3734909678.py:11: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='embarked',y='fare',data=titanic, palette=palette)
# <Axes: xlabel='embarked', ylabel='fare'>

# %%
sns.stripplot(x='embarked',y='fare',
                    data=titanic,palette=palette,jitter=1)
# Out:
# C:\Users\Tony Hu\AppData\Local\Temp\ipykernel_17736\2957273531.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='embarked',y='fare',
# <Axes: xlabel='embarked', ylabel='fare'>

# %%
sns.swarmplot(x='embarked',y='fare',data=titanic, palette=palette)
# Out:
# C:\Users\Tony Hu\AppData\Local\Temp\ipykernel_17736\2310091776.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x='embarked',y='fare',data=titanic, palette=palette)
# d:\Env\Anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 68.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\Env\Anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 22.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\Env\Anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 51.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='embarked', ylabel='fare'>
# d:\Env\Anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 78.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\Env\Anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 37.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\Env\Anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 67.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='embarked',y='age',hue='who',data=titanic)
# Out:
# d:\Env\Anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 15.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='embarked', ylabel='age'>
# d:\Env\Anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 37.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x='class',y='age',data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.boxplot(x='class',y='age',hue='who',data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.boxplot(x='age',y='class',hue='who',data=titanic)
# Out:
# <Axes: xlabel='age', ylabel='class'>

# %%
sns.violinplot(x='class',y='age',data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.violinplot(x='class',y='age',hue='who',data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.violinplot(x='class',y='age',hue='alive',
                    data=titanic,split=True)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.violinplot(x='class',y='age',hue='alive',
                    data=titanic,split=True,inner='stick')
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.violinplot(x='class',y='age',data=titanic,inner=None)
sns.swarmplot(x='class',y='age',data=titanic,color='white')
# Out:
# <Axes: xlabel='class', ylabel='age'>
# d:\Env\Anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
flights = sns.load_dataset("flights")
flights.head(10)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
# 5  1949   Jun         135
# 6  1949   Jul         148
# 7  1949   Aug         148
# 8  1949   Sep         136
# 9  1949   Oct         119

# %%
f=flights.pivot('year','month','passengers')
sns.heatmap(f)
# Out:
# C:\Users\Tony Hu\AppData\Local\Temp\ipykernel_17736\1364102141.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   f=flights.pivot('year','month','passengers')
# <Axes: xlabel='month', ylabel='year'>

# %%
sns.heatmap(f, annot=True,fmt="d")
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %%
cmap = sns.diverging_palette(200,20,sep=20,as_cmap=True)
sns.heatmap(f,cmap=cmap)
# Out:
# <Axes: xlabel='month', ylabel='year'>
